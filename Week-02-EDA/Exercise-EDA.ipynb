# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
import scipy.stats as stats

df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicated().sum())
# Out:
# 720

# %%
#  2. Modify our df to have all duplicate rows removed. 

print(df.shape)
df = df.drop_duplicates()
# Out:
# (11914, 15)

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.
print(df.shape)
# Out:
# (11194, 15)

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?

df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long our dataframe is.
df.shape
# Out:
# (11194, 15)

# %%
# * Remove any row that has a null value in it. 
df = df.dropna()

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.
df.shape
# Out:
# (11092, 15)

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 

gb = df.value_counts('Make')
gb.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Make'>

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
gb = df['Make'].value_counts()
gb.sort_index()
gb.plot(kind ='barh',x='number of models',y='Makes',figsize=(13,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
avgmsrp = df.groupby('Year')
df_2 = avgmsrp.mean()
df_2.reset_index()

timeline = sns.scatterplot(data=df_2,x='Year',y= 'MSRP')

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
df[df['Year'] <= 2000]
# Out:
#          Make         Model  Year  Engine Fuel Type  Engine HP  \
# 17       Audi           100  1992  regular unleaded      172.0
# 19       Audi           100  1992  regular unleaded      172.0
# 21       Audi           100  1992  regular unleaded      172.0
# 22       Audi           100  1993  regular unleaded      172.0
# 23       Audi           100  1993  regular unleaded      172.0
# ...       ...           ...   ...               ...        ...
# 11794  Subaru            XT  1991  regular unleaded      145.0
# 11832     GMC  Yukon Denali  2000  regular unleaded      255.0
# 11881     BMW            Z3  2000  regular unleaded      193.0
# 11882     BMW            Z3  2000  regular unleaded      193.0
# 11883     BMW            Z3  2000  regular unleaded      170.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
# Make a column where is 10 when year is less than 2000, else 1.
condition = df['Year'] <= 2000
df['adjusted_price'] = np.where(condition,df['MSRP'] * 10,df['MSRP'])

# Multiply the MSRP by the price adjuster.
cols = ['MSRP','adjusted_price']
df[df['Year'] <= 2000]
# Out:
#          Make         Model  Year  Engine Fuel Type  Engine HP  \
# 17       Audi           100  1992  regular unleaded      172.0
# 19       Audi           100  1992  regular unleaded      172.0
# 21       Audi           100  1992  regular unleaded      172.0
# 22       Audi           100  1993  regular unleaded      172.0
# 23       Audi           100  1993  regular unleaded      172.0
# ...       ...           ...   ...               ...        ...
# 11794  Subaru            XT  1991  regular unleaded      145.0
# 11832     GMC  Yukon Denali  2000  regular unleaded      255.0
# 11881     BMW            Z3  2000  regular unleaded      193.0
# 11882     BMW            Z3  2000  regular unleaded      193.0
# 11883     BMW            Z3  2000  regular unleaded      170.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices
avgmsrp = df.groupby('Year')
df_2 = avgmsrp.mean()
df_2.reset_index()
plt.ylim(0,100000)
timeline = sns.scatterplot(data=df_2,x='Year',y= 'adjusted_price')

# %% [markdown]
# # What are top 5 car makers that make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# * Use our `adjusted_price` column for this
# * Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers make the most expensive cars on average. 
makes = df.groupby('Make')
makes = makes.mean()
makes = makes.sort_values(by=['MSRP','adjusted_price'],ascending = False)
makes.head()
# Out:
#                     Year    Engine HP  Engine Cylinders  Number of Doors  \
# Make
# Bugatti      2008.333333  1001.000000         16.000000         2.000000
# Maybach      2010.937500   590.500000         12.000000         4.000000
# Rolls-Royce  2012.516129   487.548387         11.870968         3.290323
# Lamborghini  2012.730769   614.076923         10.884615         2.000000
# Bentley      2011.702703   533.851351          9.729730         2.675676
#
#              highway MPG   city mpg  Popularity          MSRP  adjusted_price
# Make
# Bugatti        14.000000   8.000000       820.0  1.757224e+06    1.757224e+06
# Maybach        16.000000  10.000000        67.0  5.462219e+05    5.462219e+05
# Rolls-Royce    19.129032  11.838710        86.0  3.511306e+05    3.511306e+05
# Lamborghini    18.019231  11.519231      1158.0  3.315673e+05    3.315673e+05
# Bentley        18.905405  11.554054       520.0  2.471693e+05    2.471693e+05

# %% [markdown]
# # What are the 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?
makes.median()
makes = makes.sort_values(by=['highway MPG'], ascending = False)
makes.head()
# Out:
#                    Year   Engine HP  Engine Cylinders  Number of Doors  \
# Make
# Alfa Romeo  2015.400000  237.000000          4.000000         2.000000
# FIAT        2016.033898  143.559322          4.000000         2.949153
# Scion       2013.416667  154.433333          4.000000         3.000000
# Honda       2013.382831  196.772622          4.682135         3.517401
# Volkswagen  2013.001773  192.673759          4.429078         3.294326
#
#             highway MPG   city mpg  Popularity          MSRP  adjusted_price
# Make
# Alfa Romeo    34.000000  24.000000       113.0  61600.000000    61600.000000
# FIAT          33.915254  26.033898       819.0  22206.016949    22206.016949
# Scion         32.300000  25.316667       105.0  19932.500000    19932.500000
# Honda         32.062645  24.719258      2202.0  26608.883991    27770.406032
# Volkswagen    32.015957  23.319149       873.0  28947.368794    29570.363475

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']
# * Create a temp_df to store the dataframe of just these values.
# * Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
condition1 = df['Make'] == 'Chevrolet'
condition2 = df['Make'] == 'Ford'
condition3 = df['Make'] == 'Toyota'
temp_df = df[condition1 | condition2 | condition3]

sns.histplot(data = temp_df,x='Make',y='adjusted_price',hue = 'Make',bins = 'auto')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='adjusted_price'>

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000
plt.xlim(0,100000)
sns.histplot(data = temp_df, x = 'adjusted_price', y = 'Make', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='adjusted_price', ylabel='Make'>

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG
sns.histplot(data = temp_df, x = 'Engine HP', y = 'highway MPG', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='highway MPG'>

# %%
plt.xlim(0,60) # remove outlier also make it look nicer
sns.histplot(data = temp_df, x = 'highway MPG', y = 'Engine HP', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='highway MPG', ylabel='Engine HP'>

# %% [markdown]
# # Using `sns.boxplot`, create a boxplot for the 'Engine HP'

# %%
# create a boxplot for the 'Engine HP'
sns.boxplot(data = temp_df, x = 'Engine HP', y = 'Make', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='Make'>

# %% [markdown]
# # Make another boxplot for highway MPG

# %%
# create a boxplot for the 'highway MPG'
sns.boxplot(data = temp_df, x = 'highway MPG', y = 'Make', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='highway MPG', ylabel='Make'>

# %% [markdown]
# # Remove any  outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# * Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# * For each column (Engine HP and highway MPG):
# * Calculate the 0.25 and 0.75 Quantiles
# * Calculate the Inter Quartile Range (IQR)
# * Create condition mask for the values that are outliers below (in the 'Minimum' range).
# * Create condition mask for the values that are outliers above (in the 'Maximum' range).
# * Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# * Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any  outliers from Engine HP and highway MPG 
temp_df.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  2599.000000  2599.000000       2599.000000      2599.000000
# mean   2010.944209   245.375144          5.849173         3.430550
# std       7.109907    98.441706          1.553867         0.855902
# min    1990.000000    55.000000          0.000000         2.000000
# 25%    2006.000000   169.000000          4.000000         3.000000
# 50%    2015.000000   231.000000          6.000000         4.000000
# 75%    2016.000000   295.000000          8.000000         4.000000
# max    2017.000000   662.000000          8.000000         4.000000
#
#        highway MPG     city mpg   Popularity           MSRP  adjusted_price
# count  2599.000000  2599.000000  2599.000000    2599.000000     2599.000000
# mean     25.271258    19.204694  2895.269334   28781.001924    32073.287803
# std       8.014079     8.706689  1878.752518   15829.675917    15103.910417
# ...

# %%
# remove engine hp outliers
Q1 = temp_df['Engine HP'].quantile(0.25)
Q3 = temp_df['Engine HP'].quantile(0.75)
IQR = Q3 - Q1
outlier_below = temp_df['Engine HP'] < (Q1 - 1.5 * IQR) # lower outlier condition
outlier_above = temp_df['Engine HP'] > (Q3 + 1.5 * IQR) # higher outlier condition
temp_df = temp_df[~(outlier_above | outlier_below)] #remove inverse of selection
temp_df.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  2563.000000  2563.000000       2563.000000      2563.000000
# mean   2010.887242   240.191572          5.818962         3.450644
# std       7.136519    88.567353          1.543539         0.844809
# min    1990.000000    55.000000          0.000000         2.000000
# 25%    2006.000000   169.000000          4.000000         3.000000
# 50%    2015.000000   225.000000          6.000000         4.000000
# 75%    2016.000000   290.000000          6.000000         4.000000
# max    2017.000000   460.000000          8.000000         4.000000
#
#        highway MPG     city mpg   Popularity          MSRP  adjusted_price
# count  2563.000000  2563.000000  2563.000000   2563.000000     2563.000000
# mean     25.323449    19.269996  2894.814280  28106.265704    31444.795162
# std       8.056322     8.749555  1876.201116  14626.351285    13982.729499
# ...

# %%
#remove highway mpg outliers
Q1 = temp_df['highway MPG'].quantile(0.25)
Q3 = temp_df['highway MPG'].quantile(0.75)
IQR = Q3 - Q1
outlier_below = temp_df['highway MPG'] < (Q1 - 1.5 * IQR) # lower outlier condition
outlier_above = temp_df['highway MPG'] > (Q3 + 1.5 * IQR) # higher outlier condition
temp_df = temp_df[~(outlier_above | outlier_below)] #remove inverse of selection
temp_df.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  2520.000000  2520.000000       2520.000000      2520.000000
# mean   2010.805952   242.203571          5.859524         3.441270
# std       7.168591    87.918817          1.514030         0.848909
# min    1990.000000    55.000000          3.000000         2.000000
# 25%    2006.000000   176.000000          4.000000         3.000000
# 50%    2015.000000   231.000000          6.000000         4.000000
# 75%    2016.000000   292.000000          8.000000         4.000000
# max    2017.000000   460.000000          8.000000         4.000000
#
#        highway MPG     city mpg   Popularity          MSRP  adjusted_price
# count  2520.000000  2520.000000  2520.000000   2520.000000     2520.000000
# mean     24.787302    18.524603  2911.861111  28154.259524    31549.755952
# std       6.419873     5.718154  1887.250276  14739.739777    14071.695558
# ...

# %% [markdown]
# # Remake the boxplots for both Engine HP and highway MPG

# %%
# Engine HP boxplot
sns.boxplot(data = temp_df, x='Engine HP', y ='Make', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='Engine HP', ylabel='Make'>

# %%
# highway MPG boxplot
sns.boxplot(data = temp_df, x = 'highway MPG', y = 'Make', hue = 'Make')
# Out:
# <AxesSubplot:xlabel='highway MPG', ylabel='Make'>

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG
sns.lmplot(data = temp_df, x = 'Engine HP', y = 'highway MPG', hue = 'Make')

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?

print('The data tells us that there is a trend that the more Engine HP a car has the less Highway MPG it will have')
# Out:
# The data tells us that there is a trend that the more Engine HP a car has the less Highway MPG it will have

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
sns.pairplot(temp_df)

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).
print("Engine HP and MSRP have a strong linear relationship because as the Engine HP increases the MSRP also increases\n")
print("City MPG and Highway MPG have a strong increasing linear relationship")
# Out:
# Engine HP and MSRP have a strong linear relationship because as the Engine HP increases the MSRP also increases
#
# City MPG and Highway MPG have a strong increasing linear relationship

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
size = plt.subplots(figsize = (8,8))
sns.heatmap(data = temp_df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

print('Engine HP has the strongest relationship with Engine Cylinders becasue according to the heatmap its color is the lightest')
# Out:
# Engine HP has the strongest relationship with Engine Cylinders becasue according to the heatmap its color is the lightest

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

temp_df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP', 'adjusted_price'],
#       dtype='object')

# %%
temp_df.columns = temp_df.columns.str.replace(' ', '_')
temp_df.columns = temp_df.columns.str.lower()

# %%
temp_df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'vehicle_size', 'vehicle_style', 'highway_mpg',
#        'city_mpg', 'popularity', 'msrp', 'adjusted_price'],
#       dtype='object')
